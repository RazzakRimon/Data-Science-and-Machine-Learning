# %%
#variable

x=100

# %%
type(x)
# Out:
# int

# %%
x=6.5

# %%
type(x)
# Out:
# float

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
print("hellow World")
# Out:
# hellow World

# %%
#Instruction
print("My", "name", "is", "Monty", "Python.", sep="-")
# Out:
# My-name-is-Monty-Python.

# %%
#Receiving Input

print("Enter your first name: ")
name = input()

print("Nice to meet you", name)
# Out:
# Enter your first name:
# Rimon
# Nice to meet you Rimon

# %%
name = input("Enter your first name: ")
print("Nice to meet you", name)
# Out:
# Enter your first name: Liza
# Nice to meet you Liza

# %%
i = input("Enter a No: ")
j = input("Enter another No: ")
sum = int(i) + int(j)
print(sum)
# Out:
# Enter a No: 5
# Enter another No: 6
# 11

# %%
#Type Conversion/Casting

#Implicit Type Conversion

num_int = 123
num_flo = 1.23
num_new = num_int + num_flo
print("datatype of num_int:",type(num_int))
print("datatype of num_flo:",type(num_flo))
print("Value of num_new:",num_new)
print("datatype of num_new:",type(num_new))
# Out:
# datatype of num_int: <class 'int'>
# datatype of num_flo: <class 'float'>
# Value of num_new: 124.23
# datatype of num_new: <class 'float'>

# %%
# Explicit Type Conversion

num_int = 123
num_str = "456"
print("Data type of num_int:",type(num_int))
print("Data type of num_str:",type(num_str))

print(num_int+num_str)
# Out:
# Data type of num_int: <class 'int'>
# Data type of num_str: <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4044889386.py in <cell line: 0>()
#       6 print("Data type of num_str:",type(num_str))
#       7
# ----> 8 print(num_int+num_str)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Boolean Type

a = True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
b = False
print(b)
print(type(b))
# Out:
# False
# <class 'bool'>
